# %% [markdown]
# <a href="https://colab.research.google.com/github/evalentin93/Com_que_roupa_eu_vou/blob/main/Projeto_Com_que_roupa_eu_vou_Tera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### [Dados Eleições 2018](https://github.com/evalentin93/Com_que_roupa_eu_vou/tree/main/Datasets/2018)

# %% [markdown]
# ####Base de dados: [Candidatos 2018](https://github.com/evalentin93/Com_que_roupa_eu_vou/tree/main/Datasets_and_Data_Dictionaries/2018/Candidatos_2018)
#
#
# *   Fonte: [TSE](https://dadosabertos.tse.jus.br/dataset/candidatos-2018)
# *   Informações contidas: Candidatos, Bens dos candidatos, Coligações, Vagas, Motivo da cassação, Propostas de governo (.pdf; não importado)
# *   Nome EDA: **df_cand_2018**; **df_bens_2018**; **df_colig_2018**; **df_vag_2018**; **df_cassa_2018**
# *   **Informações para o Brasil ou por estado**
#
#
# ---
#
#
# ####Dicionários de dados
#
#
# *   [Candidatos](https://github.com/evalentin93/Com_que_roupa_eu_vou/blob/main/Datasets_and_Data_Dictionaries/2018/Candidatos_2018/Candidatos/leiame.pdf)
# *   [Bens dos candidatos](https://github.com/evalentin93/Com_que_roupa_eu_vou/blob/main/Datasets_and_Data_Dictionaries/2018/Candidatos_2018/Bens_candidatos/leiame.pdf)
# *   [Coligações](https://github.com/evalentin93/Com_que_roupa_eu_vou/blob/main/Datasets_and_Data_Dictionaries/2018/Candidatos_2018/Coligacoes/leiame.pdf)
# *   [Vagas](https://github.com/evalentin93/Com_que_roupa_eu_vou/blob/main/Datasets_and_Data_Dictionaries/2018/Candidatos_2018/Vagas/leiame.pdf)
# *   [Motivo da cassação](https://github.com/evalentin93/Com_que_roupa_eu_vou/blob/main/Datasets_and_Data_Dictionaries/2018/Candidatos_2018/Cassacao/leiame.pdf)

# %%
df_cand_2018 = pd.read_csv('https://raw.githubusercontent.com/evalentin93/Com_que_roupa_eu_vou/main/Datasets_and_Data_Dictionaries/2018/Candidatos_2018/Candidatos/consulta_cand_2018_BRASIL.csv', encoding='latin1', sep=";")
df_cand_2018.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    DT_GERACAO HH_GERACAO  ...  DS_SITUACAO_CANDIDATO_URNA  ST_CANDIDATO_INSERIDO_URNA
# 0  30/01/2022   10:01:28  ...                    DEFERIDO                         SIM
# 1  30/01/2022   10:01:28  ...                      #NULO#                         NÃO
#
# [2 rows x 63 columns]

# %%
df_bens_2018 = pd.read_csv('https://raw.githubusercontent.com/evalentin93/Com_que_roupa_eu_vou/main/Datasets_and_Data_Dictionaries/2018/Candidatos_2018/Bens_candidatos/bem_candidato_2018_BRASIL.csv', encoding='latin1', sep=';')
df_bens_2018.head(2)
# Out:
#    DT_GERACAO HH_GERACAO  ...  DT_ULTIMA_ATUALIZACAO  HH_ULTIMA_ATUALIZACAO
# 0  30/01/2022   10:00:54  ...             28/10/2021               19:30:53
# 1  30/01/2022   10:00:54  ...             12/07/2019               19:50:00
#
# [2 rows x 19 columns]

# %%
df_colig_2018 = pd.read_csv('https://raw.githubusercontent.com/evalentin93/Com_que_roupa_eu_vou/main/Datasets_and_Data_Dictionaries/2018/Candidatos_2018/Coligacoes/consulta_coligacao_2018_BRASIL.csv', encoding='latin1', sep=';')
df_colig_2018.head(2)
# Out:
#    DT_GERACAO HH_GERACAO  ...  CD_SITUACAO_LEGENDA  DS_SITUACAO
# 0  30/01/2022   10:01:52  ...                    D     DEFERIDO
# 1  30/01/2022   10:01:52  ...                    D     DEFERIDO
#
# [2 rows x 23 columns]

# %%
df_vag_2018 = pd.read_csv('https://raw.githubusercontent.com/evalentin93/Com_que_roupa_eu_vou/main/Datasets_and_Data_Dictionaries/2018/Candidatos_2018/Vagas/consulta_vagas_2018_BRASIL.csv', encoding='latin1', sep=';')
df_vag_2018.head(2)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  ...  CD_CARGO    DS_CARGO  QT_VAGAS
# 0  30/01/2022   10:01:53         2018  ...         1  Presidente         1
# 1  30/01/2022   10:01:53         2018  ...         1  Presidente         1
#
# [2 rows x 15 columns]

# %%
df_cassa_2018 = pd.read_csv('https://raw.githubusercontent.com/evalentin93/Com_que_roupa_eu_vou/main/Datasets_and_Data_Dictionaries/2018/Candidatos_2018/Cassacao/motivo_cassacao_2018_BRASIL.csv', encoding='latin1', sep=';')
df_cassa_2018.head(2)
# Out:
#    DT_GERACAO HH_GERACAO  ...  SQ_CANDIDATO                  DS_MOTIVO_CASSACAO
# 0  30/01/2022   10:02:52  ...  250000612158  Ausência de requisito de registro
# 1  30/01/2022   10:02:52  ...  250000612154  Ausência de requisito de registro
#
# [2 rows x 12 columns]

# %% [markdown]
# ####Base de dados: [Eleitorado 2018](https://cdn.tse.jus.br/estatistica/sead/odsele/perfil_eleitorado/perfil_eleitorado_2018.zip)
#
#
# *   Fonte: [TSE](https://dadosabertos.tse.jus.br/dataset/eleitorado-2018)
# *   Informações contidas: Eleitorado, perfil do eleitorado com deficiência, eleitorado por local de votação e por seções eleitorais (todos os estados e exterior)
# *   Nome EDA: **df_eleitor_2018**
#
# ---
#
# ####Dicionários de dados
#
#
# *   [Eleitorado](https://github.com/evalentin93/Com_que_roupa_eu_vou/blob/main/Datasets_and_Data_Dictionaries/2018/Eleitorado_2018/LEIAME.pdf)

# %%
from zipfile import ZipFile
import io
from urllib.request import urlopen

r = urlopen("https://cdn.tse.jus.br/estatistica/sead/odsele/perfil_eleitorado/perfil_eleitorado_2018.zip").read()
file = ZipFile(io.BytesIO(r))
df_eleitor_2018 = pd.read_csv(file.open("perfil_eleitorado_2018.csv"), encoding='latin1', sep=';')

# %%
df_eleitor_2018.head(3)
# Out:
#    DT_GERACAO HH_GERACAO  ...  QT_ELEITORES_DEFICIENCIA QT_ELEITORES_INC_NM_SOCIAL
# 0  12/04/2021   13:55:01  ...                         1                          0
# 1  12/04/2021   13:55:01  ...                         2                          0
# 2  12/04/2021   13:55:01  ...                         4                          0
#
# [3 rows x 21 columns]

# %% [markdown]
# ####Base de dados: [Prestação de Contas Candidatos 2018](https://cdn.tse.jus.br/estatistica/sead/odsele/prestacao_contas/prestacao_de_contas_eleitorais_candidatos_2018.zip)
#
#
# *   Fonte: [TSE](https://dadosabertos.tse.jus.br/dataset/prestacao-de-contas-eleitorais-2018)
# *   Informações contidas: Despesas Contratadas Candidatos, Despesas Pagas Candidatos, Receitas Candidatos, Receitas Candidados Doador Originário
# *   Nome EDA: **df_desp_contrat_2018**, **df_desp_pagas_2018**, **df_rec_cand_2018**, **df_rec_doador_2018**
#
# ---
#
# ####Dicionários de dados
#
#
# *   [Despesas Contratadas Candidatos](https://github.com/evalentin93/Com_que_roupa_eu_vou/blob/main/Datasets_and_Data_Dictionaries/2018/Contas_2018/leiame_despesas-contratadas-candidatos.pdf)
# *   [Despesas Pagas Candidatos](https://github.com/evalentin93/Com_que_roupa_eu_vou/blob/main/Datasets_and_Data_Dictionaries/2018/Contas_2018/leiame_despesas-pagas-candidatos.pdf)
# *   [Receitas Candidatos](https://github.com/evalentin93/Com_que_roupa_eu_vou/blob/main/Datasets_and_Data_Dictionaries/2018/Contas_2018/leiame_receitas-candidatos.pdf)
# *   [Receitas Candidatos Doador Originário](https://github.com/evalentin93/Com_que_roupa_eu_vou/blob/main/Datasets_and_Data_Dictionaries/2018/Contas_2018/leiame_receitas-candidatos-doador-originario.pdf)

# %%
r = urlopen("https://cdn.tse.jus.br/estatistica/sead/odsele/prestacao_contas/prestacao_de_contas_eleitorais_candidatos_2018.zip").read()
file = ZipFile(io.BytesIO(r))
df_desp_contrat_2018 = pd.read_csv(file.open("despesas_contratadas_candidatos_2018_BRASIL.csv"), encoding='latin1', sep=';')
df_desp_pagas_2018 = pd.read_csv(file.open("despesas_pagas_candidatos_2018_BRASIL.csv"), encoding='latin1', sep=';')
df_rec_cand_2018 = pd.read_csv(file.open("receitas_candidatos_2018_BRASIL.csv"), encoding='latin1', sep=';')
df_rec_doador_2018 = pd.read_csv(file.open("receitas_candidatos_doador_originario_2018_BRASIL.csv"), encoding='latin1', sep=';')

# %%
df_desp_contrat_2018.head(3)
# Out:
#    DT_GERACAO  ... VR_DESPESA_CONTRATADA
# 0  06/02/2022  ...                197,12
# 1  06/02/2022  ...               3000,00
# 2  06/02/2022  ...                500,00
#
# [3 rows x 53 columns]

# %%
df_desp_pagas_2018.head(3)
# Out:
#    DT_GERACAO HH_GERACAO  ...                           DS_DESPESA  VR_PAGTO_DESPESA
# 0  06/02/2022   09:10:48  ...               Diversas a especificar            520,00
# 1  06/02/2022   09:10:48  ...             Publicidade por adesivos           5000,00
# 2  06/02/2022   09:10:48  ...  Publicidade por materiais impressos            650,00
#
# [3 rows x 28 columns]

# %%
df_rec_cand_2018.head(3)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  ...  DT_RECEITA DS_RECEITA  VR_RECEITA
# 0  06/02/2022   09:14:28         2018  ...  05/10/2018     #NULO#      700,00
# 1  06/02/2022   09:14:28         2018  ...  20/09/2018     #NULO#      800,00
# 2  06/02/2022   09:14:28         2018  ...  05/09/2018     #NULO#    10000,00
#
# [3 rows x 57 columns]

# %%
df_rec_doador_2018.head(3)
# Out:
#    DT_GERACAO HH_GERACAO  ...                          DS_RECEITA  VR_RECEITA
# 0  06/02/2022   09:10:34  ...  Recursos de Financiamento Coletivo       50,00
# 1  06/02/2022   09:10:34  ...  Recursos de Financiamento Coletivo      200,00
# 2  06/02/2022   09:10:34  ...  Recursos de Financiamento Coletivo       50,00
#
# [3 rows x 23 columns]

# %% [markdown]
# ####Base de dados: [Resultado 2018](https://dadosabertos.tse.jus.br/dataset/resultados-2018)
#
# *   Fonte: [TSE](https://dadosabertos.tse.jus.br/dataset/resultados-2018)
# *   Informações contidas: Votação nominal por município e zona.
# *   Nome EDA: **df_resultado_2018**
#
# ---
#
# ####Dicionários de dados
#
# *   [Votação nominal por município e zona](https://github.com/evalentin93/Com_que_roupa_eu_vou/blob/main/Datasets_and_Data_Dictionaries/2018/Resultado_2018/leiame.pdf)

# %%
r = urlopen("https://cdn.tse.jus.br/estatistica/sead/odsele/votacao_candidato_munzona/votacao_candidato_munzona_2018.zip").read()
file = ZipFile(io.BytesIO(r))
df_resultado_2018 = pd.read_csv(file.open("votacao_candidato_munzona_2018_BRASIL.csv"), encoding='latin1', sep=';')

# %%
df_resultado_2018.head(3)
# Out:
#    DT_GERACAO HH_GERACAO  ...  ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS
# 0  30/01/2022   03:44:24  ...                    N                  0
# 1  30/01/2022   03:44:24  ...                    N                  0
# 2  30/01/2022   03:44:24  ...                    N                  0
#
# [3 rows x 38 columns]

# %% [markdown]
# ### Dados Eleições 2020

# %% [markdown]
# ### Manipulação das bases de dados

# %% [markdown]
# ### EDA
